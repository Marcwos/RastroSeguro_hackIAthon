# %% [markdown]
# # 02 — Modelo de fraude
#
# Revisa artefactos entrenados por Carlos.

# %%
import json
from pathlib import Path
metrics = json.loads(Path('../reports/model_metrics.json').read_text())
print('classifier f1', metrics['fraud_classifier']['f1'])
print('anomaly overlap', metrics['anomaly_detector']['fraud_overlap_in_anomalies'])

# %%
import pandas as pd
features = pd.read_csv('../data/processed/features.csv')
print(features.shape)
print(features['etiqueta_fraude_simulada'].mean())
