# %% [markdown]
# # 01 — Exploración de datos
#
# Carga `siniestros.csv` y tablas complementarias PDF §6.2.

# %%
import pandas as pd
from pathlib import Path
ROOT = Path('..')
sin = pd.read_csv(ROOT / 'data/synthetic/siniestros.csv')
print('siniestros', sin.shape)
print(sin['ramo'].value_counts())
print(sin[['monto_pagado','estado','sucursal']].head())

# %%
pol = pd.read_csv(ROOT / 'data/synthetic/polizas.csv')
ase = pd.read_csv(ROOT / 'data/synthetic/asegurados.csv')
print('polizas', len(pol), 'asegurados', len(ase))
