# %% [markdown]
# # 03 — Evaluación del modelo
#
# Benchmark de preguntas PDF y QA del dataset.

# %%
import json
from pathlib import Path
bench = json.loads(Path('../reports/benchmark_preguntas_pdf.json').read_text())
print('preguntas PDF', len(bench['questions']))
for q in bench['questions']:
    print('-', q['question'][:60])

# %%
qa = json.loads(Path('../data/synthetic/siniestros_qa.json').read_text())
print('QA ok', qa['ok'], 'fraud_rate', qa['fraud_rate'])
